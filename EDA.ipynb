# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize

import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm

# %%
df = pd.read_csv('data/hmda_lar.csv');
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (30,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print('Data shape: ', df.shape)
# Out:
# Data shape:  (17147, 47)

# %%
df.head()
# Out:
#    tract_to_msamd_income  rate_spread  population  minority_population  \
# 0             113.360001          NaN        4231            66.510002
# 1             109.029999          NaN        7167            81.080002
# 2             139.039993          NaN        3199            34.040001
# 3             217.190002          NaN        6403            38.509998
# 4             109.029999          NaN        7167            81.080002
#
#    number_of_owner_occupied_units  number_of_1_to_4_family_units  \
# 0                             899                           1628
# 1                            1152                           2008
# 2                             795                           1252
# 3                             516                             16
# 4                            1152                           2008
#
#    loan_amount_000s  hud_median_family_income  applicant_income_000s  \
# 0               544                     73700                   96.0
# 1               320                     73700                   72.0
# 2               314                     73700                  235.0
# 3               548                     73700                  170.0
# 4               343                     73700                   82.0
#
#   state_name  ... applicant_sex_name  applicant_race_name_5  \
# 0   New York  ...               Male                    NaN
# 1   New York  ...             Female                    NaN
# 2   New York  ...               Male                    NaN
# 3   New York  ...               Male                    NaN
# 4   New York  ...               Male                    NaN
#
#   applicant_race_name_4 applicant_race_name_3 applicant_race_name_2  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#                                applicant_race_name_1  \
# 0                                              White
# 1                                              Asian
# 2  Information not provided by applicant in mail,...
# 3                                              White
# 4                                              White
#
#                             applicant_ethnicity_name  \
# 0                                 Hispanic or Latino
# 1                             Not Hispanic or Latino
# 2  Information not provided by applicant in mail,...
# 3                             Not Hispanic or Latino
# 4                                 Hispanic or Latino
#
#                                    agency_name agency_abbr action_taken_name
# 0  Department of Housing and Urban Development         HUD   Loan originated
# 1  Department of Housing and Urban Development         HUD   Loan originated
# 2  Department of Housing and Urban Development         HUD   Loan originated
# 3         Consumer Financial Protection Bureau        CFPB   Loan originated
# 4  Department of Housing and Urban Development         HUD   Loan originated
#
# [5 rows x 47 columns]

# %%
samples = [df[col].dropna().sample().values[0] if df[col].dropna().shape[0] > 0 else np.nan for col in df.columns]

# %%
def generate_summary(df):
    samples = [df[col].dropna().sample().values[0] if df[col].dropna().shape[0] > 0 else np.nan for col in df.columns]
    return pd.DataFrame({'NA Count' : df.isna().sum(), 
                  'Unique Count' : df.nunique(),
                  'Type' : df.dtypes,
                  'Sample' : samples})

# %%
df_summary = generate_summary(df)
df_summary
# Out:
#                                 NA Count  Unique Count     Type  \
# tract_to_msamd_income                  0           618  float64
# rate_spread                        16251           221  float64
# population                             0           610    int64
# minority_population                    0           579  float64
# number_of_owner_occupied_units         0           474    int64
# number_of_1_to_4_family_units          0           517    int64
# loan_amount_000s                       0          1126    int64
# hud_median_family_income               0             1    int64
# applicant_income_000s               1453           592  float64
# state_name                             0             1   object
# state_abbr                             0             1   object
# sequence_number                    17147             0  float64
# respondent_id                          0           279   object
# purchaser_type_name                    0            10   object
# property_type_name                     0             3   object
# preapproval_name                       0             3   object
# owner_occupancy_name                   0             3   object
# msamd_name                             2             1   object
# loan_type_name                         0             3   object
# loan_purpose_name                      0             3   object
# lien_status_name                       0             3   object
# hoepa_status_name                      0             2   object
# edit_status_name                   17147             0  float64
# denial_reason_name_3               17147             0  float64
# denial_reason_name_2               17147             0  float64
# denial_reason_name_1               17147             0  float64
# county_name                            0             1   object
# co_applicant_sex_name                  0             5   object
# co_applicant_race_name_5           17147             0  float64
# co_applicant_race_name_4           17147             0  float64
# co_applicant_race_name_3           17145             1   object
# co_applicant_race_name_2           17126             5   object
# co_applicant_race_name_1               0             8   object
# co_applicant_ethnicity_name            0             5   object
# census_tract_number                    0           646  float64
# as_of_year                             0             1    int64
# application_date_indicator         17147             0  float64
# applicant_sex_name                     0             4   object
# applicant_race_name_5              17147             0  float64
# applicant_race_name_4              17147             0  float64
# applicant_race_name_3              17137             3   object
# applicant_race_name_2              17066             5   object
# applicant_race_name_1                  0             7   object
# applicant_ethnicity_name               0             4   object
# agency_name                            0             6   object
# agency_abbr                            0             6   object
# action_taken_name                      0             1   object
#
#                                                                            Sample
# tract_to_msamd_income                                                       61.01
# rate_spread                                                                  2.42
# population                                                                   7318
# minority_population                                                         48.07
# number_of_owner_occupied_units                                                315
# number_of_1_to_4_family_units                                                 693
# loan_amount_000s                                                              165
# hud_median_family_income                                                    73700
# applicant_income_000s                                                         106
# state_name                                                               New York
# state_abbr                                                                     NY
# sequence_number                                                               NaN
# respondent_id                                                          7197000003
# purchaser_type_name                                             Fannie Mae (FNMA)
# property_type_name              One-to-four family dwelling (other than manufa...
# preapproval_name                                    Preapproval was not requested
# owner_occupancy_name                       Owner-occupied as a principal dwelling
# msamd_name                           New York, Jersey City, White Plains - NY, NJ
# loan_type_name                                                        FHA-insured
# loan_purpose_name                                                   Home purchase
# lien_status_name                                          Secured by a first lien
# hoepa_status_name                                                Not a HOEPA loan
# edit_status_name                                                              NaN
# denial_reason_name_3                                                          NaN
# denial_reason_name_2                                                          NaN
# denial_reason_name_1                                                          NaN
# county_name                                                         Queens County
# co_applicant_sex_name                                             No co-applicant
# co_applicant_race_name_5                                                      NaN
# co_applicant_race_name_4                                                      NaN
# co_applicant_race_name_3                Native Hawaiian or Other Pacific Islander
# co_applicant_race_name_2                                                    Asian
# co_applicant_race_name_1                                          No co-applicant
# co_applicant_ethnicity_name                                       No co-applicant
# census_tract_number                                                           871
# as_of_year                                                                   2017
# application_date_indicator                                                    NaN
# applicant_sex_name                                                           Male
# applicant_race_name_5                                                         NaN
# applicant_race_name_4                                                         NaN
# applicant_race_name_3                   Native Hawaiian or Other Pacific Islander
# applicant_race_name_2                                                       Asian
# applicant_race_name_1                                                       Asian
# applicant_ethnicity_name                                   Not Hispanic or Latino
# agency_name                             Office of the Comptroller of the Currency
# agency_abbr                                                                  FDIC
# action_taken_name                                                 Loan originated

# %%
cols_to_del = df_summary.index.values[df_summary.loc[:,'NA Count'] == df.shape[0]]
cols_to_del = set(cols_to_del)
cols_to_del
# Out:
# {'applicant_race_name_4',
#  'applicant_race_name_5',
#  'application_date_indicator',
#  'co_applicant_race_name_4',
#  'co_applicant_race_name_5',
#  'denial_reason_name_1',
#  'denial_reason_name_2',
#  'denial_reason_name_3',
#  'edit_status_name',
#  'sequence_number'}

# %%
cols_to_del = cols_to_del.union(set(['applicant_race_name_' + str(i) for i in range(1,6)]))
cols_to_del = cols_to_del.union(set(['co_applicant_race_name_' + str(i) for i in range(2,6)]))
cols_to_del = cols_to_del.union(set(['denial_reason_name_' + str(i) for i in range(1,4)]))

# %%
df.drop(list(cols_to_del), axis=1, inplace=True)

# %%
df['co_applicant_sex_name'].unique()
# Out:
# array(['Female', 'Male', 'No co-applicant',
#        'Information not provided by applicant in mail, Internet, or telephone application',
#        'Not applicable'], dtype=object)

# %%
generate_summary(df)
# Out:
#                                 NA Count  Unique Count     Type  \
# tract_to_msamd_income                  0           618  float64
# rate_spread                        16251           221  float64
# population                             0           610    int64
# minority_population                    0           579  float64
# number_of_owner_occupied_units         0           474    int64
# number_of_1_to_4_family_units          0           517    int64
# loan_amount_000s                       0          1126    int64
# hud_median_family_income               0             1    int64
# applicant_income_000s               1453           592  float64
# state_name                             0             1   object
# state_abbr                             0             1   object
# respondent_id                          0           279   object
# purchaser_type_name                    0            10   object
# property_type_name                     0             3   object
# preapproval_name                       0             3   object
# owner_occupancy_name                   0             3   object
# msamd_name                             2             1   object
# loan_type_name                         0             3   object
# loan_purpose_name                      0             3   object
# lien_status_name                       0             3   object
# hoepa_status_name                      0             2   object
# county_name                            0             1   object
# co_applicant_sex_name                  0             5   object
# co_applicant_race_name_1               0             8   object
# co_applicant_ethnicity_name            0             5   object
# census_tract_number                    0           646  float64
# as_of_year                             0             1    int64
# applicant_sex_name                     0             4   object
# applicant_ethnicity_name               0             4   object
# agency_name                            0             6   object
# agency_abbr                            0             6   object
# action_taken_name                      0             1   object
#
#                                                                            Sample
# tract_to_msamd_income                                                      109.38
# rate_spread                                                                  1.63
# population                                                                   4978
# minority_population                                                         29.74
# number_of_owner_occupied_units                                                314
# number_of_1_to_4_family_units                                                1279
# loan_amount_000s                                                              550
# hud_median_family_income                                                    73700
# applicant_income_000s                                                          56
# state_name                                                               New York
# state_abbr                                                                     NY
# respondent_id                                                          7197000003
# purchaser_type_name                                             Fannie Mae (FNMA)
# property_type_name              One-to-four family dwelling (other than manufa...
# preapproval_name                                                   Not applicable
# owner_occupancy_name                       Owner-occupied as a principal dwelling
# msamd_name                           New York, Jersey City, White Plains - NY, NJ
# loan_type_name                                                       Conventional
# loan_purpose_name                                                   Home purchase
# lien_status_name                                          Secured by a first lien
# hoepa_status_name                                                Not a HOEPA loan
# county_name                                                         Queens County
# co_applicant_sex_name                                             No co-applicant
# co_applicant_race_name_1        Information not provided by applicant in mail,...
# co_applicant_ethnicity_name                                       No co-applicant
# census_tract_number                                                          1181
# as_of_year                                                                   2017
# applicant_sex_name                                                           Male
# applicant_ethnicity_name                                   Not Hispanic or Latino
# agency_name                                  Consumer Financial Protection Bureau
# agency_abbr                                                                   HUD
# action_taken_name                                                 Loan originated

# %%
df.to_csv('data/cleaned_mortgage.csv')

# %%
st = StanfordNERTagger('models/stanford-ner/classifiers/english.muc.7class.distsim.crf.ser.gz',
                       'models/stanford-ner/stanford-ner.jar')

# %%
for col, text in zip(df_summary.index, samples):
    tokenized_text = word_tokenize(str(text))
    classified_text = st.tag(tokenized_text)
    print('Column: ', col, '\n', classified_text, '\n')
# Out:
# Column:  tract_to_msamd_income
#  [('135.94999694824222', 'O')]
#
# Column:  rate_spread
#  [('3.0', 'O')]
#
# Column:  population
#  [('2112', 'O')]
#
# Column:  minority_population
#  [('50.38999938964844', 'O')]
#
# Column:  number_of_owner_occupied_units
#  [('138', 'O')]
#
# Column:  number_of_1_to_4_family_units
#  [('956', 'O')]
#
# Column:  loan_amount_000s
#  [('326', 'O')]
#
# Column:  hud_median_family_income
#  [('73700', 'O')]
#
# Column:  applicant_income_000s
#  [('126.0', 'O')]
#
# Column:  state_name
#  [('New', 'LOCATION'), ('York', 'LOCATION')]
#
# Column:  state_abbr
#  [('NY', 'O')]
#
# Column:  sequence_number
#  [('nan', 'O')]
#
# Column:  respondent_id
#  [('0000476810', 'O')]
#
# Column:  purchaser_type_name
#  [('Loan', 'O'), ('was', 'O'), ('not', 'O'), ('originated', 'O'), ('or', 'O'), ('was', 'O'), ('not', 'O'), ('sold', 'O'), ('in', 'O'), ('calendar', 'O'), ('year', 'O'), ('covered', 'O'), ('by', 'O'), ('register', 'O')]
#
# Column:  property_type_name
#  [('One-to-four', 'O'), ('family', 'O'), ('dwelling', 'O'), ('(', 'O'), ('other', 'O'), ('than', 'O'), ('manufactured', 'O'), ('housing', 'O'), (')', 'O')]
#
# Column:  preapproval_name
#  [('Preapproval', 'O'), ('was', 'O'), ('not', 'O'), ('requested', 'O')]
#
# Column:  owner_occupancy_name
#  [('Not', 'O'), ('owner-occupied', 'O'), ('as', 'O'), ('a', 'O'), ('principal', 'O'), ('dwelling', 'O')]
#
# Column:  msamd_name
#  [('New', 'LOCATION'), ('York', 'LOCATION'), (',', 'O'), ('Jersey', 'LOCATION'), ('City', 'LOCATION'), (',', 'O'), ('White', 'LOCATION'), ('Plains', 'LOCATION'), ('-', 'O'), ('NY', 'O'), (',', 'O'), ('NJ', 'O')]
#
# Column:  loan_type_name
#  [('FHA-insured', 'O')]
#
# Column:  loan_purpose_name
#  [('Home', 'O'), ('purchase', 'O')]
#
# Column:  lien_status_name
#  [('Secured', 'O'), ('by', 'O'), ('a', 'O'), ('first', 'O'), ('lien', 'O')]
#
# Column:  hoepa_status_name
#  [('Not', 'O'), ('a', 'O'), ('HOEPA', 'O'), ('loan', 'O')]
#
# Column:  edit_status_name
#  [('nan', 'O')]
#
# Column:  denial_reason_name_3
#  [('nan', 'O')]
#
# Column:  denial_reason_name_2
#  [('nan', 'O')]
#
# Column:  denial_reason_name_1
#  [('nan', 'O')]
#
# Column:  county_name
#  [('Queens', 'LOCATION'), ('County', 'LOCATION')]
#
# Column:  co_applicant_sex_name
#  [('Information', 'O'), ('not', 'O'), ('provided', 'O'), ('by', 'O'), ('applicant', 'O'), ('in', 'O'), ('mail', 'O'), (',', 'O'), ('Internet', 'O'), (',', 'O'), ('or', 'O'), ('telephone', 'O'), ('application', 'O')]
#
# Column:  co_applicant_race_name_5
#  [('nan', 'O')]
#
# Column:  co_applicant_race_name_4
#  [('nan', 'O')]
#
# Column:  co_applicant_race_name_3
#  [('Native', 'O'), ('Hawaiian', 'O'), ('or', 'O'), ('Other', 'O'), ('Pacific', 'LOCATION'), ('Islander', 'LOCATION')]
#
# Column:  co_applicant_race_name_2
#  [('White', 'O')]
#
# Column:  co_applicant_race_name_1
#  [('No', 'O'), ('co-applicant', 'O')]
#
# Column:  co_applicant_ethnicity_name
#  [('No', 'O'), ('co-applicant', 'O')]
#
# Column:  census_tract_number
#  [('741.0', 'O')]
#
# Column:  as_of_year
#  [('2017', 'O')]
#
# Column:  application_date_indicator
#  [('nan', 'O')]
#
# Column:  applicant_sex_name
#  [('Male', 'O')]
#
# Column:  applicant_race_name_5
#  [('nan', 'O')]
#
# Column:  applicant_race_name_4
#  [('nan', 'O')]
#
# Column:  applicant_race_name_3
#  [('Native', 'O'), ('Hawaiian', 'O'), ('or', 'O'), ('Other', 'O'), ('Pacific', 'LOCATION'), ('Islander', 'LOCATION')]
#
# Column:  applicant_race_name_2
#  [('White', 'O')]
#
# Column:  applicant_race_name_1
#  [('Asian', 'O')]
#
# Column:  applicant_ethnicity_name
#  [('Not', 'O'), ('Hispanic', 'O'), ('or', 'O'), ('Latino', 'O')]
#
# Column:  agency_name
#  [('Consumer', 'ORGANIZATION'), ('Financial', 'ORGANIZATION'), ('Protection', 'ORGANIZATION'), ('Bureau', 'ORGANIZATION')]
#
# Column:  agency_abbr
#  [('HUD', 'O')]
#
# Column:  action_taken_name
#  [('Loan', 'O'), ('originated', 'O')]

# %%
df['applicant_race_name_1'].unique()
# Out:
# array(['White', 'Asian',
#        'Information not provided by applicant in mail, Internet, or telephone application',
#        'Black or African American', 'Not applicable',
#        'American Indian or Alaska Native',
#        'Native Hawaiian or Other Pacific Islander'], dtype=object)

# %%
df['applicant_sex_name'].unique()
# Out:
# array(['Male', 'Female', 'Not applicable',
#        'Information not provided by applicant in mail, Internet, or telephone application'],
#       dtype=object)

# %%
df['loan_purpose_name'].unique()
# Out:
# array(['Refinancing', 'Home purchase', 'Home improvement'], dtype=object)

# %%
nlp = en_core_web_sm.load()

# %%
# Annotations can be found here: https://spacy.io/api/annotation
for col, text in zip(df_summary.index, samples):
    doc = nlp(str(text))
    print('\n', 'Column: ', col)
    for ent in doc.ents:
        print('Text: ', ent.text, ';\tLabel: ', ent.label_)
# Out:
#  Column:  tract_to_msamd_income
#
#  Column:  rate_spread
# Text:  3.0 ;	Label:  CARDINAL
#
#  Column:  population
# Text:  2112 ;	Label:  CARDINAL
#
#  Column:  minority_population
# Text:  50.38999938964844 ;	Label:  CARDINAL
#
#  Column:  number_of_owner_occupied_units
# Text:  138 ;	Label:  CARDINAL
#
#  Column:  number_of_1_to_4_family_units
# Text:  956 ;	Label:  CARDINAL
#
#  Column:  loan_amount_000s
# Text:  326 ;	Label:  CARDINAL
#
#  Column:  hud_median_family_income
# Text:  73700 ;	Label:  CARDINAL
#
#  Column:  applicant_income_000s
# Text:  126.0 ;	Label:  CARDINAL
#
#  Column:  state_name
# Text:  New York ;	Label:  GPE
#
#  Column:  state_abbr
#
#  Column:  sequence_number
#
#  Column:  respondent_id
# Text:  0000476810 ;	Label:  CARDINAL
#
#  Column:  purchaser_type_name
# Text:  calendar year ;	Label:  DATE
#
#  Column:  property_type_name
# Text:  One ;	Label:  CARDINAL
#
#  Column:  preapproval_name
#
#  Column:  owner_occupancy_name
#
#  Column:  msamd_name
# Text:  New York ;	Label:  GPE
# Text:  Jersey City ;	Label:  GPE
# Text:  White Plains - NY ;	Label:  PERSON
# Text:  NJ ;	Label:  GPE
#
#  Column:  loan_type_name
# Text:  FHA ;	Label:  ORG
#
#  Column:  loan_purpose_name
#
#  Column:  lien_status_name
#
#  Column:  hoepa_status_name
# Text:  HOEPA ;	Label:  ORG
#
#  Column:  edit_status_name
#
#  Column:  denial_reason_name_3
#
#  Column:  denial_reason_name_2
#
#  Column:  denial_reason_name_1
#
#  Column:  county_name
# Text:  Queens County ;	Label:  GPE
#
#  Column:  co_applicant_sex_name
#
#  Column:  co_applicant_race_name_5
#
#  Column:  co_applicant_race_name_4
#
#  Column:  co_applicant_race_name_3
# Text:  Hawaiian ;	Label:  NORP
#
#  Column:  co_applicant_race_name_2
#
#  Column:  co_applicant_race_name_1
#
#  Column:  co_applicant_ethnicity_name
#
#  Column:  census_tract_number
# Text:  741.0 ;	Label:  CARDINAL
#
#  Column:  as_of_year
# Text:  2017 ;	Label:  DATE
#
#  Column:  application_date_indicator
#
#  Column:  applicant_sex_name
#
#  Column:  applicant_race_name_5
#
#  Column:  applicant_race_name_4
#
#  Column:  applicant_race_name_3
# Text:  Hawaiian ;	Label:  NORP
#
#  Column:  applicant_race_name_2
#
#  Column:  applicant_race_name_1
# Text:  Asian ;	Label:  NORP
#
#  Column:  applicant_ethnicity_name
# Text:  Hispanic ;	Label:  NORP
# Text:  Latino ;	Label:  PERSON
#
#  Column:  agency_name
# Text:  Consumer Financial Protection Bureau ;	Label:  ORG
#
#  Column:  agency_abbr
# Text:  HUD ;	Label:  ORG
#
#  Column:  action_taken_name
